# %% [markdown]
# # 02: Likelihood Plots

# %% [markdown]
# In this notebook we obtain the likelihood plots for the 2d Scenarios (IV, V, VI and XI).
# We first calculate the likelihood in a grid and save the results.

# %% [markdown]
# ## Calculations

# %%
from parscanning import GridScan
from SMEFT19.SMEFTglob import likelihood_fits
from SMEFT19.scenarios import scIV, scV, scVI, scXI
import flavio
import warnings

# %% [markdown]
# ### Scenario IV

# %%
xmin = -2.0
xmax = 2.0
ymin = -2.0
ymax = 2.0
xmargin = 0.02*(xmax-xmin)
ymargin = 0.02*(ymax-ymin)
GS = GridScan(likelihood_fits, [xmin-xmargin, ymin-ymargin], [xmax+xmargin, ymax+ymargin], 50)
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    GS.run_mp(4, scIV)
GS.save_csv('../../likelihood/likelihood_IV.dat')

# %% [markdown]
# ### Scenario V

# %%
xmin = -1.0
xmax = 1.0
ymin = -2.0
ymax = 2.0
xmargin = 0.02*(xmax-xmin)
ymargin = 0.02*(ymax-ymin)
GS = GridScan(likelihood_fits, [xmin-xmargin, ymin-ymargin], [xmax+xmargin, ymax+ymargin], 50)
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    GS.run_mp(4, scV)
GS.save_csv('../../likelihood/likelihood_V.dat')

# %% [markdown]
# ### Scenario VI

# %%
xmin = -1.0
xmax = 1.0
ymin = -2.0
ymax = 2.0
xmargin = 0.02*(xmax-xmin)
ymargin = 0.02*(ymax-ymin)
GS = GridScan(likelihood_fits, [xmin-xmargin, ymin-ymargin], [xmax+xmargin, ymax+ymargin], 50)
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    GS.run_mp(4, scVI)
GS.save_csv('../../likelihood/likelihood_VI.dat')

# %% [markdown]
# ### Scenario XI

# %%
xmin = -1.0
xmax = 1.0
ymin = -2.0
ymax = 2.0
xmargin = 0.02*(xmax-xmin)
ymargin = 0.02*(ymax-ymin)
GS = GridScan(likelihood_fits, [xmin-xmargin, ymin-ymargin], [xmax+xmargin, ymax+ymargin], 50)
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    GS.run_mp(4, scXI)
GS.save_csv('../../likelihood/likelihood_XI.dat')

# %% [markdown]
# ## Plotting

# %% [markdown]
# Now we define the function used to read the data for the grids of points and to format it so we can plot it.

# %%
import numpy as np
import pandas as pd
from SMEFT19.plots import likelihood_plot

# %%
def read_meshgrid(fname, stepx=50, stepy=50):
    zdata = pd.read_csv(fname, sep='\t')
    xcoords = np.linspace(zdata['x'].min(), zdata['x'].max(), stepx)
    ycoords = np.linspace(zdata['y'].min(), zdata['y'].max(), stepy)
    fitcodes = {r'$R_{K^{(*)}}$':'likelihood_lfu_fcnc.yaml', r'$R_{D^{(*)}}$':'likelihood_rd_rds.yaml',
                'EW':'likelihood_ewpt.yaml', 'eeWW':'likelihood_eeww.yaml', 'Global':'global'}
    d = {}
    for k, v in zip(fitcodes.keys(), fitcodes.values()):
        z = np.array(zdata[v]).reshape(stepx, stepy)
        d.update({k:z})
    d['EW'] = d['EW'] + d['eeWW']
    d.pop('eeWW')
    return (xcoords, ycoords, d)

# %% [markdown]
# ### Scenario IV

# %%
likelihood_plot(read_meshgrid('../../likelihood/likelihood_IV.dat'), -2.0, 2.0, -2.0, 2.0,
                [r'$C_{\ell q}^e$', r'$C_{\ell q}^\mu$'], locleg='lower right', colors=[0,1,2,4],
                bf=[-0.1511,0.152], widths=[1.5,]*4, fout='../../plots/scIV')

# %% [markdown]
# ### Scenario V

# %%
likelihood_plot(read_meshgrid('../../likelihood/likelihood_V.dat'), -1.0, 1.0, -2.0, 2.0,
                [r'$C_{\ell q}^e$', r'$C_{\ell q}^\tau$'], locleg='upper right', colors=[0,1,2,4],
                bf=[-0.1467,-0.2998], widths=[1.5,]*4, fout='../../plots/scV')

# %% [markdown]
# ### Scenario VI

# %%
likelihood_plot(read_meshgrid('../../likelihood/likelihood_VI.dat'), -1.0, 1.0, -2.0, 2.0,
                [r'$C_{\ell q}^\mu$', r'$C_{\ell q}^\tau$'], locleg='upper left', colors=[0,1,2,4],
                bf=[0.152,-0.271], widths=[1.5,]*4, fout='../../plots/scVI')

# %% [markdown]
# ### Scenario XI

# %%
likelihood_plot(read_meshgrid('../../likelihood/likelihood_XI.dat'), -1.0, 1.0, -2.0, 2.0,
                [r'$C_{\ell q}^e = -C_{\ell q}^\mu$', r'$C_{\ell q}^\tau$'], locleg='upper right',
                colors=[0,1,2,4], bf=[-0.14988535, -0.26939863], widths=[1.5,]*4, fout='../../plots/scXI')

# %% [markdown]
# ## Nuclear beta decays

# %%
import SMEFT19
from collections import OrderedDict

# %%
beta_obs = ['Ft(10C)', 'Ft(14O)', 'Ft(22Mg)', 'Ft(26mAl)', 'Ft(34Cl)', 'Ft(34Ar)', 'Ft(38mK)', 'Ft(38Ca)',
            'Ft(42Sc)', 'Ft(46V)', 'Ft(50Mn)', 'Ft(54Co)', 'Ft(62Ga)', 'Ft(74Rb)']
SMEFT19.SMEFTglob.restart_smelli(include_likelihoods=['fast_likelihood_quarks.yaml'],
                                 custom_likelihoods={'beta':beta_obs})

# %%
xmin = -2.0
xmax = 2.0
ymin = -2.0
ymax = 2.0
xmargin = 0.02*(xmax-xmin)
ymargin = 0.02*(ymax-ymin)
GS = GridScan(likelihood_fits, [xmin-xmargin, ymin-ymargin], [xmax+xmargin, ymax+ymargin], 50)
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    GS.run_mp(4, scIV)
GS.save_csv('../../likelihood/likelihood_IV_beta.dat')

# %%
xmin = -1.0
xmax = 1.0
ymin = -2.0
ymax = 2.0
xmargin = 0.02*(xmax-xmin)
ymargin = 0.02*(ymax-ymin)
GS = GridScan(likelihood_fits, [xmin-xmargin, ymin-ymargin], [xmax+xmargin, ymax+ymargin], 50)
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    GS.run_mp(4, scV)
GS.save_csv('../../likelihood/likelihood_V_beta.dat')

# %%
xmin = -1.0
xmax = 1.0
ymin = -2.0
ymax = 2.0
xmargin = 0.02*(xmax-xmin)
ymargin = 0.02*(ymax-ymin)
GS = GridScan(likelihood_fits, [xmin-xmargin, ymin-ymargin], [xmax+xmargin, ymax+ymargin], 50)
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    GS.run_mp(4, scVI)
GS.save_csv('../../likelihood/likelihood_VI_beta.dat')

# %%
xmin = -1.0
xmax = 1.0
ymin = -2.0
ymax = 2.0
xmargin = 0.02*(xmax-xmin)
ymargin = 0.02*(ymax-ymin)
GS = GridScan(likelihood_fits, [xmin-xmargin, ymin-ymargin], [xmax+xmargin, ymax+ymargin], 50)
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    GS.run_mp(4, scXI)
GS.save_csv('../../likelihood/likelihood_XI_beta.dat')

# %%
def read_meshgrid2(fname, stepx=50, stepy=50):
    zdata = pd.read_csv(fname[0], sep='\t')
    zdata_beta = pd.read_csv(fname[1], sep='\t')
    xcoords = np.linspace(zdata['x'].min(), zdata['x'].max(), stepx)
    ycoords = np.linspace(zdata['y'].min(), zdata['y'].max(), stepy)
    fitcodes = {r'$R_{K^{(*)}}$':'likelihood_lfu_fcnc.yaml', r'$R_{D^{(*)}}$':'likelihood_rd_rds.yaml',
                'EW':'likelihood_ewpt.yaml', 'eeWW':'likelihood_eeww.yaml', 'Global':'global'}
    d = OrderedDict()
    for k, v in zip(fitcodes.keys(), fitcodes.values()):
        z = np.array(zdata[v]).reshape(stepx, stepy)
        d.update({k:z})
    d['EW'] = d['EW'] + d['eeWW']
    d[r'Nuclear $\beta$'] = np.array(zdata_beta['custom_beta']).reshape(stepx, stepy)
    d.move_to_end('Global')
    d.pop('eeWW')
    return (xcoords, ycoords, d)

# %%
likelihood_plot(read_meshgrid2(['../../likelihood/likelihood_IV.dat', '../../likelihood/likelihood_IV_beta.dat']),
                -2.0, 2.0, -2.0, 2.0, [r'$C_{\ell q}^e$', r'$C_{\ell q}^\mu$'], locleg='upper left',
                colors=[0,1,2,3,4], bf=[-0.1511,0.152], widths=[1.5,]*5, fout='../../plots/scIVbeta')
# Out:
# linewidths is ignored by contourf

# %%
likelihood_plot(read_meshgrid2(['../../likelihood/likelihood_VI.dat','../../likelihood/likelihood_VI_beta.dat']),
                -1.0, 1.0, -2.0, 2.0, [r'$C_{\ell q}^\mu$', r'$C_{\ell q}^\tau$'], locleg='upper left',
                colors=[0,1,2,3,4], bf=[0.152,-0.271], widths=[1.5,]*5, fout='../../plots/scVI_beta')
# Out:
# linewidths is ignored by contourf

# %%
likelihood_plot(read_meshgrid2(['../../likelihood/likelihood_XI.dat','../../likelihood/likelihood_XI_beta.dat']),
                -1.0, 1.0, -2.0, 2.0, [r'$C_{\ell q}^e = -C_{\ell q}^\mu$', r'$C_{\ell q}^\tau$'],
                locleg='upper right', colors=[0,1,2,3,4], bf=[-0.14988535, -0.26939863], widths=[1.5,]*5,
                fout='../../plots/scXI_beta')
