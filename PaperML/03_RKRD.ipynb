# %% [markdown]
# # 03: RK and RD

# %%
import SMEFT19
from SMEFT19.scenarios import rotBI, rotBII
# Out:
# /opt/conda/envs/smeft19/lib/python3.8/site-packages/xgboost/compat.py:93: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
SMEFT19.obsuncert.calculate(rotBI, [-0.25, -0.03, 0], [0.0, 0.03, 3.5],
                            '../data/observables/obsBI.yaml',
                            '../data/ellipses/rotBI.yaml', name='Scenario I',
                            mode='exact', cores=4)
# Out:
# 3 of the measurements of 'Rtaul(B->Dlnu)' are multivariate. This can lead to inconsistent results as the other observables are profiled over. To be consistent, you should perform a multivariate combination that is not yet supported by `combine_measurements`.
# 3 of the measurements of 'Rtaul(B->D*lnu)' are multivariate. This can lead to inconsistent results as the other observables are profiled over. To be consistent, you should perform a multivariate combination that is not yet supported by `combine_measurements`.

# %%
SMEFT19.obsuncert.calculate(rotBII, [-0.25, -0.15, -0.03, -0.12, 0],
                            [0.0, 0.15, 0.03, 0.07, 3.5],
                            '../data/observables/obsBII.yaml',
                            '../data/ellipses/rotBII.yaml',
                            name='Scenario II', mode='exact', cores=4)
# Out:
# 3 of the measurements of 'Rtaul(B->Dlnu)' are multivariate. This can lead to inconsistent results as the other observables are profiled over. To be consistent, you should perform a multivariate combination that is not yet supported by `combine_measurements`.
# 3 of the measurements of 'Rtaul(B->D*lnu)' are multivariate. This can lead to inconsistent results as the other observables are profiled over. To be consistent, you should perform a multivariate combination that is not yet supported by `combine_measurements`.

# %%
SMEFT19.plots.error_plot('../data/plots/rotRKplot', 'RK',
                         ['../data/observables/obsBI.yaml',
                          '../data/observables/obsBII.yaml'],
                         legend=1)

# %%
SMEFT19.plots.error_plot('../data/plots/rotRDplot', 'RD',
                         ['../data/observables/obsBI.yaml',
                          '../data/observables/obsBII.yaml'], legend=0)
